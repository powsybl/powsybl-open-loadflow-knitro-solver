# %%
import pandas as pd
import pypowsybl.network as pn
import pypowsybl as pp
from pypowsybl_jupyter import nad_explorer
import re
import networkx as nx
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt
import numpy as np
import builtins
import itertools
import importlib
import utils

from utils import edges_with_impedance, median,cluster_subgraph,network_construction, type_controller, unique_list, plot_slack_cluster, slack_subgraph_2nd, plot_graph, dfs_slack_2nd, slack_subgraph, has_slack, visualize_graph, dfs_with_slack, median

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from 'd:\\dev\\powsybl-open-loadflow-knitro-solver\\utils.py'>

# %%
network_name = "test_active_power_and_correction_all_load_ieee/ieee300"
network ="ieee300"
extension_in = '.xiidm'
network = pn.load('./Outputs/' + network +"-"+"active-perturbation" + extension_in)
edges = edges_with_impedance(network) 
G = nx.from_pandas_edgelist(edges,'bus1_id','bus2_id', edge_attr=True,create_using=nx.Graph())
dist_weighted = dict(nx.shortest_path_length(G, weight="impedance_module"))
dist = dict(nx.shortest_path_length(G))

# %%
load_B = [x.strip() for x in """
B1-L,B2-L, B3-L, B5-L, B6-L, B8-L, B9-L, B10-L, B11-L, B13-L, B14-L, B15-L, B17-L, B20-L, B21-L, B22-L, B23-L, B25-L, B26-L, B27-L, B33-L, B37-L, B38-L, B40-L, B41-L, B43-L, B44-L, B47-L, B48-L, B49-L, B52-L, B53-L, B54-L, B55-L, B57-L, B58-L, B59-L, B61-L, B63-L, B70-L, B71-L, B72-L, B73-L, B76-L, B77-L, B79-L, B80-L, B84-L, B89-L, B90-L, B91-L, B92-L, B94-L, B97-L, B98-L, B99-L, B102-L, B103-L, B104-L, B105-L, B107-L, B108-L, B109-L, B110-L, B112-L, B113-L, B114-L, B121-L, B124-L, B118-L, B120-L, B122-L, B123-L, B125-L, B126-L, B127-L, B135-L, B136-L, B137-L, B138-L, B139-L, B140-L, B141-L, B142-L, B143-L, B148-L, B145-L, B152-L, B154-L, B155-L, B156-L, B157-L, B159-L, B161-L, B162-L, B167-L, B170-L, B171-L, B172-L, B173-L, B175-L, B176-L, B177-L, B178-L, B179-L, B180-L, B181-L, B182-L, B183-L, B184-L, B186-L, B187-L, B188-L, B189-L, B191-L, B192-L, B204-L, B196-L, B197-L, B198-L, B199-L, B200-L, B201-L, B202-L, B203-L, B206-L, B208-L, B209-L, B211-L, B214-L, B215-L, B216-L, B217-L, B218-L, B220-L, B221-L, B222-L, B223-L, B224-L, B225-L, B227-L, B228-L, B229-L, B231-L, B232-L, B233-L, B234-L, B235-L, B238-L, B243-L, B245-L, B246-L, B247-L, B248-L, B249-L, B319-L, B320-L, B322-L, B324-L, B526-L, B528-L, B531-L, B562-L, B609-L, B1190-L, B9003-L, B9004-L, B9021-L, B9022-L, B9024-L, B9025-L, B9026-L, B9031-L, B9032-L, B9033-L, B9034-L, B9035-L, B9037-L, B9038-L, B9036-L, B9041-L, B9042-L, B9043-L, B9052-L, B9071-L, B9072-L, B9121-L, B9533-L
""".split(",") if x.strip()]

# %%
len(load_B)
# Out:
# 188

# %%
# # slack_info 
# network_name = "test_active_power_and_correction_more_ieee/ieee300/ieee300"
# network ="ieee300"
# pertubation = "active-perturbation"
# data = pd.read_csv(
#     network_name +"_" + pertubation + ".csv",
#     sep=";",
#     engine="python",
#     index_col=False,
#    # on_bad_lines="skip",
# )
# optim_info = pd.read_csv(
#     network_name + "_" + pertubation + "_optim_info.csv",
#     sep=";",
#     engine="python",
#     index_col=False,
# )
# extension_in = '.xiidm'
# network = pn.load('./Outputs/' + network +"-"+pertubation + extension_in)
# edges = edges_with_impedance(network)

# data_grouped = data.groupby('busId')[['type','slackValue_pu','slackValue','gen','controlevoltage','transfo','shunt','load','info']].agg(unique_list)
# data_grouped['Total_slack_abs'] = data_grouped['slackValue_pu'].apply(lambda x: builtins.sum(abs(slack) for slack in x) if isinstance(x, list) else abs(x))
# G, dist, pos = network_construction(edges, data_grouped)
# clusters = slack_subgraph(G, data_grouped)
# data_grouped = cluster_subgraph(G, clusters, data_grouped, dist)
# fig = plot_slack_cluster(G, pos, clusters,data_grouped,data, col_centroid='centroid')
# fig.show()

# %%
optim_info = pd.read_csv( 
    network_name  +"_load0/ieee300_load0_active-perturbation"
   + "_optim_info.csv",
    sep=";",
    engine="python",
    index_col=False,
)
optim_info
# Out:
#    total_penalty   penaltyP  penaltyQ  penaltyV  status  iterations
# 0      19.716704  14.061971  0.000001  5.654731    -104          36

# %%
# slack_info 
load_id =0
pertubation = "_load"
distances_resume = pd.DataFrame(columns=["test number", "load_name", "source_node", "main_centroid", "distance_to_centroid", "total_penalty", "penaltyP", "penaltyQ", "penaltyV"])

for load_id in range(0,188):
    load_str = str(load_id)
    if load_id == 29:
        continue
        
    data = pd.read_csv(
    network_name  + pertubation +load_str+"/ieee300_load"+load_str+"_active-perturbation"+ ".csv",
    sep=";",
    engine="python",
    index_col=False,
   # on_bad_lines="skip",
)
    optim_info = pd.read_csv( 
    network_name  + pertubation +load_str+"/ieee300_load"+load_str+"_active-perturbation"
   + "_optim_info.csv",
    sep=";",
    engine="python",
    index_col=False,
)

    data_grouped = data.groupby('busId')[['type','slackValue_pu','slackValue','gen','controlevoltage','transfo','shunt','load']].agg(unique_list)
    data_grouped['Total_slack_abs'] = data_grouped['slackValue_pu'].apply(lambda x: builtins.sum(abs(slack) for slack in x) if isinstance(x, list) else abs(x))
    G,dist_w, pos = network_construction(edges, data_grouped)
    clusters = slack_subgraph(G, data_grouped)
    data_grouped = cluster_subgraph(G, clusters, data_grouped, dist_w)

    load_name = load_B[load_id]
    source_node = network.get_loads().loc[load_name, "bus_id"]
    sum_p_abs_idx = pd.to_numeric(data_grouped['sum_P'], errors='coerce').abs().idxmax()
    main_centroid = data_grouped.loc[sum_p_abs_idx, 'centroid'] ## main centroid ? by size or total slack ? 
    
    # distance_w_uv = dist_weighted[source_node][main_centroid]
    distance_uv = dist[main_centroid][source_node]

    # distance = nx.shortest_path_length(G, source=source_node, target=main_centroid)
    # distance_weighted = nx.shortest_path_length(G, source=source_node, target=main_centroid, weight='impedance_module')
### regarder distance sans barycentre ? ou avec ?? 

    new_row = pd.DataFrame([{
        "test number": load_id,
        "load_name": load_name,
        "source_node": source_node,
        "main_centroid": main_centroid,
        "distance_to_centroid": distance_uv,
        # "distance_weighted_to_centroid": distance_w_uv,
        "total_penalty": optim_info.loc[0, "total_penalty"] if not optim_info.empty else np.nan,
        "penaltyP": optim_info.loc[0, "penaltyP"] if not optim_info.empty else np.nan,
        "penaltyQ": optim_info.loc[0, "penaltyQ"] if not optim_info.empty else np.nan,
        "penaltyV": optim_info.loc[0, "penaltyV"] if not optim_info.empty else np.nan,
        "status": optim_info.loc[0, "status"] if not optim_info.empty else np.nan, 
        "iterations": optim_info.loc[0, "iterations"] if not optim_info.empty else np.nan,
    }])

    distances_resume = pd.concat([distances_resume, new_row], ignore_index=True)

  

    #opti_resume = pd.DataFrame(summary_rows)
    # fig = plot_slack_cluster(G, pos, clusters,data_grouped,data, col_centroid='centroid')
    # fig.show()
# Out:
# Focal bus perturbation VL3_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL3_0_load'])
# Focal bus perturbation VL319_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL319_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL173_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL173_0_shunt_compensators'], ['VL173_0_load'])
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL15_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL15_1_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL3_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL3_0_load'])
# Focal bus perturbation VL319_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL319_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL15_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL15_1_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL3_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL3_0_load'])
# Focal bus perturbation VL319_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL319_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL138_0 is a plossible correcting bus cluster of type P, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL138_0', controllerElements=[VL138_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B138-G'], [nan], [nan], ['VL138_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL5_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL5_0_load'])
# Focal bus perturbation VL14_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL14_0_load'])
# Focal bus perturbation VL27_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL27_0_load'])
# Focal bus perturbation VL110_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL110_0_load'])
# Focal bus perturbation VL76_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL76_0', controllerElements=[VL76_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B76-G'], [nan], [nan], ['VL76_0_load'])
# Focal bus perturbation VL76_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL70_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL70_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL126_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL126_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL173_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL173_0_shunt_compensators'], ['VL173_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL201_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL201_0_load'])
# Focal bus perturbation VL7001_2 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7001_2', controllerElements=[VL7001_2], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7003-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7001_2 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL15_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL15_1_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL3_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL3_0_load'])
# Focal bus perturbation VL319_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL319_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL173_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL173_0_shunt_compensators'], ['VL173_0_load'])
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL15_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL15_1_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL3_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL3_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7_0 has dominant slack P but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, VL3_0 with distance 1.5870000000000002 and bus with ([nan], [nan], [nan], [nan], ['VL3_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL11_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL11_0_load'])
# Focal bus perturbation VL70_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL70_0_load'])
# Focal bus perturbation VL76_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL76_0', controllerElements=[VL76_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B76-G'], [nan, nan], [nan], ['VL76_0_load'])
# Focal bus perturbation VL76_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL126_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL126_0_load'])
# Focal bus perturbation VL173_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL173_0_shunt_compensators'], ['VL173_0_load'])
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL7001_2 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7001_2', controllerElements=[VL7001_2], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7003-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7001_2 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL15_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL15_1_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9031_2 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL9031_2_load'])
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL8_0 is a plossible correcting bus cluster of type P, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL8_0', controllerElements=[VL8_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B8-G'], [nan, nan], [nan], ['VL8_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL173_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL173_0_shunt_compensators'], ['VL173_0_load'])
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7_0 has dominant slack P but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, VL3_0 with distance 1.5870000000000002 and bus with ([nan], [nan], [nan], [nan], ['VL3_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL173_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL173_0_shunt_compensators'], ['VL173_0_load'])
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL138_0 is a plossible correcting bus cluster of type P, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL138_0', controllerElements=[VL138_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B138-G'], [nan], [nan], ['VL138_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL8_0 is a plossible correcting bus cluster of type P, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL8_0', controllerElements=[VL8_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B8-G'], [nan, nan], [nan], ['VL8_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL191_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL191_0', controllerElements=[VL191_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B191-G'], [nan], [nan], ['VL191_0_load'])
# Focal bus perturbation VL191_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL202_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL202_0_load'])
# Focal bus perturbation VL200_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL200_0_load'])
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9031_2 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL9031_2_load'])
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL15_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL15_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL126_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL126_0_load'])
# Focal bus perturbation VL173_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL173_0_shunt_compensators'], ['VL173_0_load'])
# Focal bus perturbation VL179_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL179_0_shunt_compensators'], ['VL179_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL191_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL191_0', controllerElements=[VL191_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B191-G'], [nan], [nan], ['VL191_0_load'])
# Focal bus perturbation VL191_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7001_1 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7001_1', controllerElements=[VL7001_1], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7002-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7001_1 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7001_2 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7001_2', controllerElements=[VL7001_2], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7003-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7001_2 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL222_0 is a plossible correcting bus cluster of type P, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL222_0', controllerElements=[VL222_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B222-G'], [nan], [nan], ['VL222_0_load'])
# Focal bus perturbation VL9031_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL9031_0_load'])
# Focal bus perturbation VL9031_2 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL9031_2_load'])
# Focal bus perturbation VL9031_6 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL9031_6_load'])
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL15_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL15_1_load'])
# Focal bus perturbation VL20_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL20_0', controllerElements=[VL20_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B20-G'], [nan], [nan], ['VL20_0_load'])
# Focal bus perturbation VL20_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL70_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL70_0_load'])
# Focal bus perturbation VL76_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL76_0', controllerElements=[VL76_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B76-G'], [nan], [nan], ['VL76_0_load'])
# Focal bus perturbation VL76_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL114_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL114_0_load'])
# Focal bus perturbation VL526_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL526_0_load'])
# Focal bus perturbation VL562_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL562_0_load'])
# Focal bus perturbation VL609_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL609_0_load'])
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL98_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL98_0', controllerElements=[VL98_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B98-G'], [nan], [nan], ['VL98_0_load'])
# Focal bus perturbation VL98_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL108_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL108_0', controllerElements=[VL108_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B108-G'], [nan], [nan], ['VL108_0_load'])
# Focal bus perturbation VL108_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL123_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], [nan], ['VL123_0_load'])
# Focal bus perturbation VL154_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL154_0_shunt_compensators'], ['VL154_0_load'])
# Focal bus perturbation VL160_0 has dominant slack P but no suitable controller
#  WARNING: NO other possible nodes (cluster of 1)
# Focal bus perturbation VL173_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL173_0_shunt_compensators'], ['VL173_0_load'])
# Focal bus perturbation VL190_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL190_0', controllerElements=[VL190_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B190-G'], [nan], ['VL190_0_shunt_compensators'], [nan])
# Focal bus perturbation VL190_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL248_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan], ['VL248_0_shunt_compensators'], ['VL248_0_load'])
# Focal bus perturbation VL7001_1 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7001_1', controllerElements=[VL7001_1], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7002-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7001_1 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7001_2 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7001_2', controllerElements=[VL7001_2], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7003-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7001_2 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7011_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7011_0', controllerElements=[VL7011_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7011-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7011_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
# ...
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9004_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan], ['VL9004_0_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9021_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan, nan], ['VL9021_0_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9002_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9002_0', controllerElements=[VL9002_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9002-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9002_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9022_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan, nan], ['VL9022_0_load'])
# Focal bus perturbation VL9024_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan, nan], ['VL9024_0_load'])
# Focal bus perturbation VL9002_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9002_0', controllerElements=[VL9002_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9002-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9002_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9025_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan, nan], ['VL9025_0_load'])
# Focal bus perturbation VL9002_0 is a plossible correcting bus cluster of type P, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9002_0', controllerElements=[VL9002_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9002-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9025_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan, nan], ['VL9025_1_load'])
# Focal bus perturbation VL9031_0 is a plossible correcting bus cluster of type P, bus with ([nan, nan], [nan, nan], [nan, nan], [nan], ['VL9031_0_load'])
# Focal bus perturbation VL9031_1 is a plossible correcting bus cluster of type P, bus with ([nan, nan], [nan, nan], [nan, nan], [nan], ['VL9031_1_load'])
# Focal bus perturbation VL9031_2 is a plossible correcting bus cluster of type P, bus with ([nan, nan], [nan, nan], [nan, nan], [nan], ['VL9031_2_load'])
# Focal bus perturbation VL9031_3 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], ['VL9031_3_shunt_compensators'], ['VL9031_3_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9031_4 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan], ['VL9031_4_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9031_5 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan], ['VL9031_5_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9031_6 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan], ['VL9031_6_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9036_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan], ['VL9036_0_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9041_0 is a plossible correcting bus cluster of type P, bus with ([nan, nan], [nan, nan], [nan, nan], [nan], ['VL9041_0_load'])
# Focal bus perturbation VL9041_1 is a plossible correcting bus cluster of type P, bus with ([nan, nan], [nan, nan], [nan, nan], [nan], ['VL9041_1_load'])
# Focal bus perturbation VL9043_0 is a plossible correcting bus cluster of type P, bus with ([nan, nan], [nan, nan], [nan, nan], [nan], ['VL9043_0_load'])
# Focal bus perturbation VL9002_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9002_0', controllerElements=[VL9002_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9002-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9002_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL8_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL8_0', controllerElements=[VL8_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B8-G'], [nan], [nan], ['VL8_0_load'])
# Focal bus perturbation VL8_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL76_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL76_0', controllerElements=[VL76_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B76-G'], [nan], [nan], ['VL76_0_load'])
# Focal bus perturbation VL76_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL91_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL91_0', controllerElements=[VL91_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B91-G'], [nan], [nan], ['VL91_0_load'])
# Focal bus perturbation VL91_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL92_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL92_0', controllerElements=[VL92_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B92-G'], [nan], [nan], ['VL92_0_load'])
# Focal bus perturbation VL92_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL108_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL108_0', controllerElements=[VL108_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B108-G'], [nan], [nan], ['VL108_0_load'])
# Focal bus perturbation VL108_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL190_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL190_0', controllerElements=[VL190_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B190-G'], [nan], ['VL190_0_shunt_compensators'], [nan])
# Focal bus perturbation VL190_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7001_2 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7001_2', controllerElements=[VL7001_2], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7003-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7001_2 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7017_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7017_0', controllerElements=[VL7017_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7017-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7017_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_0', controllerElements=[VL9051_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9051-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan], ['VL9051_1_load'])
# Focal bus perturbation VL9051_2 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_2', controllerElements=[VL9051_2], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9053-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_2 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_3 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_3', controllerElements=[VL9051_3], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9054-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_3 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9051_4 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL9051_4', controllerElements=[VL9051_4], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B9055-G'], [nan], [nan], [nan])
# Focal bus perturbation VL9051_4 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9071_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan], ['VL9071_0_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9071_1 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan], ['VL9071_1_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9121_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan, nan], ['VL9121_0_load'])
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL9533_0 is a plossible correcting bus cluster of type P, bus with ([nan], [nan], [nan, nan], [nan, nan], ['VL9533_0_load'])

# %%
distances_resume["status_name"] = np.select(
    [   distances_resume["status"].eq(0),
        distances_resume["status"].between(-199, -100, inclusive="both"),
        distances_resume["status"].eq(-410),
        distances_resume["status"].eq(-400),
    ],
    [   "CONVERGED_TO_LOCAL_OPTIMUM",
        "converged to feasible approximate solution",
        "Max iterations",
        "Max iterations",
    ],
    default="other"
)

# %%
distances_resume
# Out:
#     test number load_name source_node main_centroid distance_to_centroid  \
# 0             0      B1-L       VL1_0         VL3_0                    1
# 1             1      B2-L       VL1_1         VL3_0                    1
# 2             2      B3-L       VL3_0         VL3_0                    0
# 3             3      B5-L       VL5_0       VL126_0                    5
# 4             4      B6-L       VL5_1         VL3_0                    2
# ..          ...       ...         ...           ...                  ...
# 182         183   B9052-L    VL9051_1      VL9051_1                    0
# 183         184   B9071-L    VL9071_0      VL9071_0                    0
# 184         185   B9072-L    VL9071_1      VL9071_1                    0
# 185         186   B9121-L    VL9121_0      VL9121_0                    0
# 186         187   B9533-L    VL9533_0      VL9533_0                    0
#
#     total_penalty    penaltyP   penaltyQ   penaltyV  status  iterations  \
# 0       19.716704   14.061971   0.000001   5.654731  -104.0        36.0
# 1       20.664679   15.146252   0.000005   5.518422  -104.0        35.0
# 2       20.445325   15.325009        0.0   5.120315  -104.0        44.0
# 3       11.859458    6.324917        0.0   5.534541     0.0        37.0
# 4       18.792192   13.211355        0.0   5.580837  -104.0        33.0
# ..            ...         ...        ...        ...     ...         ...
# 182    445.845445   395.24364  31.184642  19.417163  -104.0        39.0
# 183    604.687579  596.213707   8.283866   0.190006  -104.0        35.0
# 184    594.502585  582.675386  11.034963   0.792237  -104.0        30.0
# 185    570.815975  554.168142  13.326033     3.3218  -104.0        33.0
# 186    496.436011  481.464681  13.098888   1.872442  -104.0        23.0
#
#                                     status_name
# 0    converged to feasible approximate solution
# 1    converged to feasible approximate solution
# 2    converged to feasible approximate solution
# 3                    CONVERGED_TO_LOCAL_OPTIMUM
# 4    converged to feasible approximate solution
# ..                                          ...
# 182  converged to feasible approximate solution
# 183  converged to feasible approximate solution
# 184  converged to feasible approximate solution
# 185  converged to feasible approximate solution
# 186  converged to feasible approximate solution
#
# [187 rows x 12 columns]

# %%
# sum_p_abs_idx = pd.to_numeric(data_grouped['sum_P'], errors='coerce').abs().idxmax()
# main_centroid = data_grouped.loc[sum_p_abs_idx, 'centroid']
# main_centroid

# %%
# Frequency of distance_to_centroid split by status
freq_status = (
    distances_resume
    .groupby(["distance_to_centroid"])
    .size()
  
    .sort_index()
)

ax = freq_status.plot(kind="bar", stacked=True, figsize=(8, 4), colormap="tab10")
ax.set_xlabel("distance_to_centroid")
ax.set_ylabel("frequency")
ax.set_title("Distribution of distance to main centroid by status")
plt.xticks(rotation=0)
# custom_labels = {
#     "-410.0": "Max iteration reached",
#     "-104.0": "converged to feasible approximate solution",
#     "-400.0": "Max iterations"
# }

# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles, [custom_labels.get(lbl, lbl) for lbl in labels], title="solver status")
plt.tight_layout()
plt.show()

# %%
distances_resume['distance_to_centroid'].value_counts()
# Out:
# distance_to_centroid
# 0     97
# 1     45
# 2     21
# 3     10
# 4      8
# 5      5
# 12     1
# Name: count, dtype: int64

# %%
distances_resume.loc[distances_resume['distance_to_centroid'] == 12]
# Out:
#    test number load_name source_node main_centroid distance_to_centroid  \
# 78          79    B138-L     VL138_0      VL7039_0                   12
#
#    total_penalty  penaltyP penaltyQ penaltyV  status  iterations  \
# 78      2.519871  0.000001      0.0  2.51987     0.0        18.0
#
#                    status_name
# 78  CONVERGED_TO_LOCAL_OPTIMUM

# %%
# Boxplots for iterations and distance_to_centroid
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

distances_resume["distance_to_centroid"].plot(
    kind="box",
    ax=axes[0],
    grid=True
)
axes[0].set_title("Distance to centroid")

distances_resume["iterations"].plot(
    kind="box",
    ax=axes[1],
    grid=True
)
axes[1].set_title("Iterations")

fig.suptitle("Boxplots of distance to centroid and iterations")
plt.tight_layout()
plt.show()

# %%
# slack_info 
pertubation1 = "load79/ieee300_load79_active-perturbation"
data_correction3 = pd.read_csv(
    network_name +"_" + pertubation1 + ".csv",
    sep=";",
    engine="python",
    index_col=False,
   # on_bad_lines="skip",
)
# network = pn.load('./Outputs/' + network_name+"-corrected-"+pertubation1 + extension_in)
#new_row = pd.read_csv(network_name+"_"+pertubation1+"_optim_info.csv", sep=";", engine="python", index_col=False)
optim_info = pd.concat([optim_info, new_row], ignore_index=True)
data_grouped_3 = data_correction3.groupby('busId')[['type','slackValue_pu','slackValue','gen','controlevoltage','transfo','shunt','load']].agg(unique_list)
data_grouped_3['Total_slack_abs'] = data_grouped_3['slackValue_pu'].apply(lambda x: builtins.sum(abs(slack) for slack in x) if isinstance(x, list) else abs(x))
# data_grouped_3 = data_grouped_3.join(
#     V_nom.drop_duplicates(subset='bus_id')[selected_columns].set_index('bus_id'),
#     how='left'
# )
G_3, dist, pos = network_construction(edges, data_grouped_3)
clusters = slack_subgraph(G_3, data_grouped_3)
data_grouped_3 = cluster_subgraph(G_3, clusters, data_grouped_3, dist)
fig = plot_slack_cluster(G_3, pos, clusters,data_grouped_3,data, col_centroid='centroid')
fig.show()
# Out:
# Focal bus perturbation VL7039_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7039_0', controllerElements=[VL7039_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7039-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7039_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)
# Focal bus perturbation VL7049_0 is a plossible correcting bus, cluster of type V, bus with (["VoltageControl(type=GENERATOR, controlledBus='VL7049_0', controllerElements=[VL7049_0], mergeStatus=MAIN, mergedDependentVoltageControlsSize=0)"], ['B7049-G'], [nan], [nan], [nan])
# Focal bus perturbation VL7049_0 has dominant slack V but no suitable controller
#  WARNING: NEED TO FIND OTHER CORRECTING BUS, NO other possible nodes (cluster of 1)

# %%
len(distances_resume)

# %%
status_counts = distances_resume["status"].value_counts()
status_counts

# %%
# Keep only converged-to-feasible-approximate-solution cases
freq_status = (
    distances_resume[distances_resume["status_name"] == "converged to feasible approximate solution"]
    .groupby("distance_to_centroid")
    .size()
    .sort_index()
)

ax = freq_status.plot(kind="bar", figsize=(8, 4), color="steelblue")
ax.set_xlabel("distance_to_centroid")
ax.set_ylabel("frequency")
ax.set_title("Distance to main centroid (converged to feasible approximate solution only)")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Frequency of distance_to_centroid
freq_10 = distances_resume.head(20)
freq = (
    freq_10
    .groupby(["distance_to_centroid", "status_name"])
    .size()
    .unstack(fill_value=0)
    .sort_index()
)


ax = freq.plot(kind="bar", figsize=(6, 4), color="steelblue")
ax.set_xlabel("distance_to_centroid")
ax.set_ylabel("frequency")
ax.set_title("Distribution of the distance to the main centroid for the load perturbations")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
print(f"mean :", freq_10['distance_to_centroid'].mean())
print(f"median :", freq_10['distance_to_centroid'].median())
print(f"std :", freq_10['distance_to_centroid'].std())

# %%
freq

# %%
status_counts = distances_resume["status"].value_counts()
status_counts

# %%
print(f"mean :", distances_resume['distance_to_centroid'].mean())
print(f"median :", distances_resume['distance_to_centroid'].median())
print(f"std :", distances_resume['distance_to_centroid'].std())
# Out:
# mean : 0.9946524064171123
# median : 0.0
# std : 1.5222271678603478

# %%
# # Frequency of distance_to_centroid
# freq = distances_table["distance_weighted_to_centroid"].value_counts().sort_index()

# freq = distances_table["distance_weighted_to_centroid"].round(2).value_counts().sort_index()
# ax = freq.plot(kind="bar", figsize=(25, 4), color="steelblue")
# ax.set_xlabel("distance_weighted_to_centroid (rounded)")
# ax.set_ylabel("frequency")
# ax.set_title("Frequency of distance_weighted_to_centroid")
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %%
distances_table

# %%
# Frequency of distance_to_centroid
freq = distances_table["distance_weighted_to_centroid"].value_counts().sort_index()

ax = freq.plot(kind="bar", figsize=(6, 4), color="steelblue")
ax.set_xlabel("distance_to_centroid")
ax.set_ylabel("frequency")
ax.set_title("Frequency of distance_to_centroid")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
distances_table

# %%
G

# %%
distances_table["source_node"].value_counts()

# %%
distances_table.groupby("main_centroid")["distance_to_centroid"].mean()

# %%
sum_p = pd.to_numeric(data_grouped['sum_P'], errors='coerce').idxmax()
sum_p

# %%
load_B[1]

# %%
network.get_loads()[network.get_loads().index == load_B[1]]['bus_id'].iloc[0]

# %%
# distances = []
# source_node = network.get_loads()[network.get_loads().index == load_B[1]]['bus_id'].iloc[0]
# centroid = pd.to_numeric(data_grouped['sum_P'], errors='coerce').idxmax()
d = nx.shortest_path_length(G, source=source_node, target=main_centroid)
d
